# %% [markdown]
# # Air Quality Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import folium

import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

print('Pandas version:', pd.__version__) # 2.2.3
print('Numpy version:', np.__version__) # 1.26.4
print('Seaborn version:', sns.__version__) # 0.13.2
# Out:
# Pandas version: 2.2.3
# Numpy version: 1.26.4
# Seaborn version: 0.13.2

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv('./data/cleaned_data.csv')
df.head()
# Out:
#          Date Latitude Longitude    PM1  PM2.5   PM10   NO2 Sensor_ID
# 0  2021-01-12  51,4568    5,4383  12.57  14.43  18.98   7.0       I07
# 1  2021-01-13  51,4568    5,4383   2.95   4.30   9.31  18.0       I07
# 2  2021-01-14  51,4567    5,4382   7.14   9.92  19.15  35.0       I07
# 3  2021-01-15  51,4567    5,4382   6.45   8.39  14.20  28.0       I07
# 4  2021-01-16  51,4567    5,4382  15.00  16.44  20.35  31.0       I07

# %%
df['Latitude'] = df['Latitude'].astype(str).str.replace(',', '.').astype(float)
df['Longitude'] = df['Longitude'].astype(str).str.replace(',', '.').astype(float)

df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Latitude            float64
# Longitude           float64
# PM1                 float64
# PM2.5               float64
# PM10                float64
# NO2                 float64
# Sensor_ID            object
# dtype: object

# %%
sensor_coordinates = df.groupby('Sensor_ID')[['Latitude', 'Longitude']].apply(lambda group: group.mode().iloc[0])

eindhoven_map = folium.Map(location=[51.4416, 5.4697], zoom_start=12, scrollWheelZoom=False)

for sensor_id, row in sensor_coordinates.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        icon=folium.DivIcon(html=f"""
            <div style="
                font-size: 10px;
                color: white;
                background: green;
                border-radius: 50%;
                text-align: center;
                width: 30px;
                height: 30px;
                display: flex;
                justify-content: center;
                align-items: center;
                border: 1px solid black;">
                {sensor_id}
            </div>
        """),
    ).add_to(eindhoven_map)

eindhoven_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c966a31c450e4c56135eb389f1b0f4f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c966a31c450e4c56135eb389f1b0f4f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c966a31c450e4c56135eb389f1b0f4f4 = L.map(
#                 &quot;map_c966a31c450e4c56135eb389f1b0f4f4&quot;,
#                 {
#                     center: [51.4416, 5.4697],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b948dd5607d3501dbe7ddd99d03cd95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3b948dd5607d3501dbe7ddd99d03cd95.addTo(map_c966a31c450e4c56135eb389f1b0f4f4);
#
#
#             var marker_58b44a9cd97eab8489f3175783037fe4 = L.marker(
#                 [51.4568, 5.4384],
#                 {}
#             ).addTo(map_c966a31c450e4c56135eb389f1b0f4f4);
#
#
#             var div_icon_66e01dca6723efecbaa0ad74b01c1670 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                font-size: 10px;\n                color: white;\n                background: green;\n                border-radius: 50%;\n                text-align: center;\n                width: 30px;\n                height: 30px;\n                display: flex;\n                justify-content: center;\n                align-items: center;\n                border: 1px solid black;\&quot;\u003e\n                I07\n            \u003c/div\u003e\n        &quot;});
#             marker_58b44a9cd97eab8489f3175783037fe4.setIcon(div_icon_66e01dca6723efecbaa0ad74b01c1670);
#
#
#             var marker_4da611eaf0bfd8a0ee6408ac164a4fad = L.marker(
#                 [51.4415, 5.4714],
#                 {}
#             ).addTo(map_c966a31c450e4c56135eb389f1b0f4f4);
#
#
#             var div_icon_7df5ff4f5428cccb88ce659522646845 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                font-size: 10px;\n                color: white;\n                background: green;\n                border-radius: 50%;\n                text-align: center;\n                width: 30px;\n                height: 30px;\n                display: flex;\n                justify-content: center;\n                align-items: center;\n                border: 1px solid black;\&quot;\u003e\n                I12\n            \u003c/div\u003e\n        &quot;});
#             marker_4da611eaf0bfd8a0ee6408ac164a4fad.setIcon(div_icon_7df5ff4f5428cccb88ce659522646845);
#
#
#             var marker_5cfc438723d62b3a0478d557e0d005f7 = L.marker(
#                 [51.4136, 5.4707],
#                 {}
#             ).addTo(map_c966a31c450e4c56135eb389f1b0f4f4);
#
#
#             var div_icon_29848d973d3814f6b1a18e9c7c091331 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                font-size: 10px;\n                color: white;\n                background: green;\n                border-radius: 50%;\n                text-align: center;\n                width: 30px;\n                height: 30px;\n                display: flex;\n                justify-content: center;\n                align-items: center;\n                border: 1px solid black;\&quot;\u003e\n                I17\n            \u003c/div\u003e\n        &quot;});
#             marker_5cfc438723d62b3a0478d557e0d005f7.setIcon(div_icon_29848d973d3814f6b1a18e9c7c091331);
#
#
#             var marker_eb03f600d7790f673a5fce54fa8d31ce = L.marker(
#                 [51.4332, 5.5198],
#                 {}
#             ).addTo(map_c966a31c450e4c56135eb389f1b0f4f4);
#
#
#             var div_icon_38695661b795ada55a95c53f66fa934d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;\n                font-size: 10px;\n                color: white;\n                background: green;\n                border-radius: 50%;\n                text-align: center;\n                width: 30px;\n                height: 30px;\n                display: flex;\n                justify-content: center;\n                align-items: center;\n                border: 1px solid black;\&quot;\u003e\n                I19\n            \u003c/div\u003e\n        &quot;});
#             marker_eb03f600d7790f673a5fce54fa8d31ce.setIcon(div_icon_38695661b795ada55a95c53f66fa934d);
#
#
#             var marker_5c1b37bcc5e5929567357dadd41cc0f2 = L.marker(
#                 [51.4375, 5.4517],
#                 {}
#             ).addTo(map_c966a31c450e4c56135eb389f1b0f4f4);
#
#
#             var div_icon_db098cc4bb3ffceb8868545ace4710ef = L.divIc

# %% [markdown]
# Since the UHI data is an average of the months June, Juli and August of 2022 we will also take the average of the values of the sensors for these months.

# %%
start_date = '2022-06-01'
end_date = '2022-08-31'

df_filtered = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

average_values = (
    df_filtered.groupby('Sensor_ID')[['PM1', 'PM2.5', 'PM10', 'NO2']]
    .mean()
    .reset_index()
)

mode_coords = df_filtered.groupby('Sensor_ID')[['Latitude', 'Longitude']].agg(lambda x: x.mode()[0]).reset_index()

average_values = average_values.merge(mode_coords, on='Sensor_ID', how='left')

average_values
# Out:
#   Sensor_ID        PM1      PM2.5       PM10        NO2  Latitude  Longitude
# 0       I07   4.290000   5.312500  10.531304  18.554348   51.4568     5.4383
# 1       I12   7.587500   9.175588  16.493971  11.955882   51.4416     5.4714
# 2       I17   6.769130   8.295000  14.146739  21.413043   51.4136     5.4707
# 3       I19   6.910778   8.591333  17.882556  22.088889   51.4332     5.5198
# 4       I30   6.484778   8.196333  17.676222  17.433333   51.4375     5.4518
# 5       I36   8.633371  10.531573  19.163034  20.449438   51.4387     5.4817
# 6       I37  10.433696  11.966739  20.024022  18.978261   51.4686     5.4723

# %%
# df_average = pd.DataFrame(average_values)

# def normalise_column(df, column):
#     return (df[column] - df[column].min()) / (df[column].max() - df[column].min())

# df_normalised = pd.DataFrame({
#     'Sensor_ID': df_average['Sensor_ID'],
#     'PM1': normalise_column(df_average, 'PM1'),
#     'PM2.5': normalise_column(df_average, 'PM2.5'),
#     'PM10': normalise_column(df_average, 'PM10'),
#     'NO2': normalise_column(df_average, 'NO2'),
#     'Latitude': df_average['Latitude'],
#     'Longitude': df_average['Longitude']
# })

# df_normalised

# %%
import folium
import pandas as pd
from folium import FeatureGroup
from matplotlib import cm, colors

def normalize_values(values, cmap_name='coolwarm'):
    cmap = cm.get_cmap(cmap_name)
    norm = colors.Normalize(vmin=min(values), vmax=max(values))
    return [colors.rgb2hex(cmap(norm(value))) for value in values]

def add_parameter_layer(map_object, df, parameter, layer_name):
    valid_rows = df[df[parameter].notnull()]
    if valid_rows.empty:
        print(f"No data available for {parameter}. Skipping layer.")
        return
    
    values = valid_rows[parameter].tolist()
    color_map = normalize_values(values)
    
    layer = FeatureGroup(name=layer_name)
    
    for index, row in valid_rows.iterrows():
        value = row[parameter]
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            icon=folium.DivIcon(html=f"""
                <div style="
                    font-size: 12px;
                    color: black;
                    text-align: center;
                    background-color: {color_map[index % len(color_map)]};
                    border-radius: 50%;
                    text-align: center;
                    width: 40px;
                    height: 40px;
                    display: flex;
                    justify-content: center;
                    align-items: center;
                    border: 1px solid black;">
                    {value:.2f}
                </div>
            """),
            popup=folium.Popup(f"Sensor: {row['Sensor_ID']}<br>{parameter}: {value:.2f}"),
            tooltip=f"Sensor: {row['Sensor_ID']}<br>{parameter}"
        ).add_to(layer)
    
    map_object.add_child(layer)
    
    return layer

eindhoven_map = folium.Map(location=[51.4416, 5.4697], zoom_start=13, scrollWheelZoom=False)

df_normalised['Latitude'] = pd.to_numeric(df_normalised['Latitude'], errors='coerce')
df_normalised['Longitude'] = pd.to_numeric(df_normalised['Longitude'], errors='coerce')

layers = {
    'PM1': add_parameter_layer(eindhoven_map, average_values, 'PM1', 'PM1 Levels'),
    'PM2.5': add_parameter_layer(eindhoven_map, average_values, 'PM2.5', 'PM2.5 Levels'),
    'PM10': add_parameter_layer(eindhoven_map, average_values, 'PM10', 'PM10 Levels'),
    'NO2': add_parameter_layer(eindhoven_map, average_values, 'NO2', 'NO2 Levels')
}

folium.LayerControl().add_to(eindhoven_map)

# eindhoven_map.save("eindhoven_pollution_map.html")
eindhoven_map
# Out:
# /var/folders/qp/02j4_gk9273413dxs9s5_c4m0000gn/T/ipykernel_20932/3871931697.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap(cmap_name)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8886fdc0f6c5d3edd991d31044d01ddf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8886fdc0f6c5d3edd991d31044d01ddf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8886fdc0f6c5d3edd991d31044d01ddf = L.map(
#                 &quot;map_8886fdc0f6c5d3edd991d31044d01ddf&quot;,
#                 {
#                     center: [51.4416, 5.4697],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca2c34f7fd51a2bfad75e3795d5aab80 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ca2c34f7fd51a2bfad75e3795d5aab80.addTo(map_8886fdc0f6c5d3edd991d31044d01ddf);
#
#
#             var feature_group_4a35bc9ba10c11d359a0cb56c0977936 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_88f2e121a55df0cca5c2a2d2569fdc69 = L.marker(
#                 [51.4568, 5.4383],
#                 {}
#             ).addTo(feature_group_4a35bc9ba10c11d359a0cb56c0977936);
#
#
#             var div_icon_ab3858d5d417c58aa34a59162730b16c = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    font-size: 12px;\n                    color: black;\n                    text-align: center;\n                    background-color: #3b4cc0;\n                    border-radius: 50%;\n                    text-align: center;\n                    width: 40px;\n                    height: 40px;\n                    display: flex;\n                    justify-content: center;\n                    align-items: center;\n                    border: 1px solid black;\&quot;\u003e\n                    4.29\n                \u003c/div\u003e\n            &quot;});
#             marker_88f2e121a55df0cca5c2a2d2569fdc69.setIcon(div_icon_ab3858d5d417c58aa34a59162730b16c);
#
#
#         var popup_3bcc58dfd6bb91e3cabe4b6e0923b815 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6cd995a234a25808324145d0472d00a = $(`&lt;div id=&quot;html_c6cd995a234a25808324145d0472d00a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sensor: I07&lt;br&gt;PM1: 4.29&lt;/div&gt;`)[0];
#                 popup_3bcc58dfd6bb91e3cabe4b6e0923b815.setContent(html_c6cd995a234a25808324145d0472d00a);
#
#
#
#         marker_88f2e121a55df0cca5c2a2d2569fdc69.bindPopup(popup_3bcc58dfd6bb91e3cabe4b6e0923b815)
#         ;
#
#
#
#
#             marker_88f2e121a55df0cca5c2a2d2569fdc69.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor: I07&lt;br&gt;PM1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e0527033f36c2b991ccdbfa7469cc395 = L.marker(
#                 [51.4416, 5.4714],
#                 {}
#             ).addTo(feature_group_4a35bc9ba10c11d359a0cb56c0977936);
#
#
#             var div_icon_61891a3924a4e781bfe8c7f1f2129a5d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    font-size: 12px;\n                    color: black;\n                    text-align: center;\n                    background-color: #e6d7cf;\n                    border-radius: 50%;\n                    text-align: center;\n                    width: 40px;\n                    height: 40px;\n                    display: flex;\n                    justify-content: center;\n                    align-items: center;\n                    border: 1px solid black;\&quot;\u003e\n                    7.59\n                \u003c/div\u003e\n            &quot;});
#             marker_e0527033f36c2b991ccdbfa7469cc395.setIcon(div_icon_61891a3924a4e781bfe8c7f1f2129a5d);
#
#
#         var popup_a9b29519079d1e6a11b829ca49769b75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0926d3a4b6e3a741888cddd636bb23cb = $(`&lt;div id=&quot;html_0926d3a4b6e3a741888cddd636bb23cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sensor: I12&lt;br&gt;PM1: 7.59&lt;/div&gt;`)[0];
#                 popup_a9b29519079d1e6a11b829ca49769b75.setContent(html_0926d3a4b6e3a741888cddd636bb23cb);
#
#
#
#         marker_e0527033f36c2b991ccdbfa7469cc395.bindPopup(popup_a9b29519079d1e6a11b829ca49769b75)
#         ;
#
#
#
#
#             marker_e0527033f36c2b991ccdbfa7469cc395.bindTooltip(
#                 `&lt;div&gt;
#                      Sensor: I12&lt;br&gt;PM1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_db123faf88a31cb30b13add21b5e29a9 = L.marker(
#                 [51.4136, 5.4707],
